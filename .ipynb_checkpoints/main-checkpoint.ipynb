# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
import seaborn as sns

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

consumer_key = "gHLqjBEtV9FwPEYoPY7reAyvL"
consumer_secret = "gMAfuuI13GCSKGZxO3PF9ZR5sDFTghq44Uuw3Ece5hs9OTSC9z"
access_token = "977543336377581568-xnRHASGqgdszCGzvHgYquWL2hjkEXZS"
access_token_secret = "ZYZz0sorPDL3tuafQWCEDWIDAn4uqi0c8gszGq7HefTLS"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
sentiments = []
target_list = ["@BBC", "@CBS", "@CNN", "@FoxNews", "@NYTimes"]

# %%
for user in target_list:
    counter = 1
    for page in range(5):
        tweets = api.user_timeline(user,page=page+1)
        for tweet in tweets:
            com = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            tweets_ago = counter
            sentiments.append({"Date": tweet["created_at"],
                               "User": user,
                               "Text": tweet["text"],
                               "Compound": com,
                               "Positive": pos,
                               "Neutral": neu,
                               "Negative": neg,
                               "Tweets Ago": counter})
            counter = counter + 1

# %%
sent_df = pd.DataFrame.from_dict(sentiments)
sent_df = sent_df[["User","Date","Tweets Ago","Compound","Positive","Neutral","Negative","Text"]]
sent_df.to_csv("output.csv")
sent_df
# Out:
#          User                            Date  Tweets Ago  Compound  Positive  \
# 0        @BBC  Thu Mar 29 20:41:00 +0000 2018           1   -0.2960     0.000
# 1        @BBC  Thu Mar 29 18:45:08 +0000 2018           2    0.0000     0.000
# 2        @BBC  Thu Mar 29 18:44:20 +0000 2018           3    0.0000     0.000
# 3        @BBC  Thu Mar 29 18:44:11 +0000 2018           4    0.0000     0.000
# 4        @BBC  Thu Mar 29 18:43:51 +0000 2018           5    0.0000     0.000
# 5        @BBC  Thu Mar 29 18:05:02 +0000 2018           6    0.4522     0.194
# 6        @BBC  Thu Mar 29 17:04:05 +0000 2018           7    0.0000     0.000
# 7        @BBC  Thu Mar 29 16:12:19 +0000 2018           8    0.7840     0.288
# 8        @BBC  Thu Mar 29 16:03:03 +0000 2018           9   -0.3164     0.000
# 9        @BBC  Thu Mar 29 15:41:25 +0000 2018          10    0.0000     0.000
# 10       @BBC  Thu Mar 29 15:31:22 +0000 2018          11    0.0000     0.000
# 11       @BBC  Thu Mar 29 15:26:27 +0000 2018          12    0.0000     0.000
# 12       @BBC  Thu Mar 29 15:24:08 +0000 2018          13    0.0000     0.000
# 13       @BBC  Thu Mar 29 15:04:02 +0000 2018          14    0.0000     0.000
# 14       @BBC  Thu Mar 29 14:21:11 +0000 2018          15    0.0000     0.000
# 15       @BBC  Thu Mar 29 14:07:48 +0000 2018          16    0.0000     0.000
# 16       @BBC  Thu Mar 29 12:31:03 +0000 2018          17    0.8268     0.299
# 17       @BBC  Thu Mar 29 11:00:21 +0000 2018          18   -0.6249     0.124
# 18       @BBC  Thu Mar 29 10:18:02 +0000 2018          19    0.6908     0.231
# 19       @BBC  Thu Mar 29 08:00:12 +0000 2018          20    0.7840     0.345
# 20       @BBC  Thu Mar 29 07:27:07 +0000 2018          21    0.0000     0.000
# 21       @BBC  Thu Mar 29 07:00:10 +0000 2018          22    0.0000     0.000
# 22       @BBC  Wed Mar 28 18:00:05 +0000 2018          23    0.0000     0.000
# 23       @BBC  Wed Mar 28 17:00:12 +0000 2018          24    0.2960     0.109
# 24       @BBC  Wed Mar 28 16:30:00 +0000 2018          25   -0.8225     0.000
# 25       @BBC  Wed Mar 28 16:00:10 +0000 2018          26    0.0000     0.000
# 26       @BBC  Wed Mar 28 15:35:27 +0000 2018          27    0.7506     0.280
# 27       @BBC  Wed Mar 28 13:32:04 +0000 2018          28    0.0000     0.000
# 28       @BBC  Wed Mar 28 12:26:01 +0000 2018          29   -0.3182     0.000
# 29       @BBC  Wed Mar 28 11:50:54 +0000 2018          30    0.0000     0.000
# ..        ...                             ...         ...       ...       ...
# 470  @NYTimes  Thu Mar 29 11:30:09 +0000 2018          71    0.0000     0.000
# 471  @NYTimes  Thu Mar 29 11:14:03 +0000 2018          72    0.8020     0.325
# 472  @NYTimes  Thu Mar 29 10:59:02 +0000 2018          73    0.0000     0.000
# 473  @NYTimes  Thu Mar 29 10:44:04 +0000 2018          74    0.0000     0.000
# 474  @NYTimes  Thu Mar 29 10:30:08 +0000 2018          75    0.0000     0.000
# 475  @NYTimes  Thu Mar 29 10:16:01 +0000 2018          76    0.0000     0.000
# 476  @NYTimes  Thu Mar 29 10:00:19 +0000 2018          77    0.0000     0.000
# 477  @NYTimes  Thu Mar 29 09:44:04 +0000 2018          78   -0.4588     0.000
# 478  @NYTimes  Thu Mar 29 09:30:11 +0000 2018          79   -0.4767     0.000
# 479  @NYTimes  Thu Mar 29 09:15:04 +0000 2018          80   -0.8625     0.000
# 480  @NYTimes  Thu Mar 29 09:00:12 +0000 2018          81    0.2960     0.115
# 481  @NYTimes  Thu Mar 29 08:45:03 +0000 2018          82   -0.6908     0.000
# 482  @NYTimes  Thu Mar 29 08:30:08 +0000 2018          83    0.0000     0.000
# 483  @NYTimes  Thu Mar 29 08:14:03 +0000 2018          84    0.6908     0.263
# 484  @NYTimes  Thu Mar 29 08:02:06 +0000 2018          85   -0.2960     0.000
# 485  @NYTimes  Thu Mar 29 07:47:05 +0000 2018          86   -0.5423     0.000
# 486  @NYTimes  Thu Mar 29 07:32:06 +0000 2018          87   -0.6369     0.000
# 487  @NYTimes  Thu Mar 29 07:26:50 +0000 2018          88    0.0000     0.000
# 488  @NYTimes  Thu Mar 29 07:17:07 +0000 2018          89    0.3612     0.215
# 489  @NYTimes  Thu Mar 29 07:08:18 +0000 2018          90    0.6808     0.444
# 490  @NYTimes  Thu Mar 29 07:02:05 +0000 2018          91   -0.6619     0.151
# 491  @NYTimes  Thu Mar 29 06:31:05 +0000 2018          92    0.6249     0.170
# 492  @NYTimes  Thu Mar 29 05:59:27 +0000 2018          93    0.0000     0.000
# 493  @NYTimes  Thu Mar 29 05:41:06 +0000 2018          94    0.2023     0.083
# 494  @NYTimes  Thu Mar 29 05:21:04 +0000 2018          95    0.4404     0.244
# 495  @NYTimes  Thu Mar 29 05:02:02 +0000 2018          96    0.0000     0.000
# 496  @NYTimes  Thu Mar 29 04:41:06 +0000 2018          97   -0.7778     0.074
# 497  @NYTimes  Thu Mar 29 04:21:04 +0000 2018          98    0.0000     0.000
# 498  @NYTimes  Thu Mar 29 04:08:47 +0000 2018          99    0.0000     0.000
# 499  @NYTimes  Thu Mar 29 04:02:02 +0000 2018         100    0.7783     0.328
#
#      Neutral  Negative                                               Text
# 0      0.901     0.099  At a time when men thought women shouldn't spe...
# 1      1.000     0.000  RT @BBCBreakfast: Counting down the hours unti...
# 2      1.000     0.000  RT @bbcrb: Retirement's looking rosy for Hank ...
# 3      1.000     0.000  RT @BBCNewsbeat: Anthony Joshua faces Joseph P...
# 4      1.000     0.000  RT @BBCOne: Anyone else having a 'chilled one'...
# 5      0.697     0.109  ❤️ 'That was it I just totally fell in love wi...
# 6      1.000     0.000  🍳 Wanna get the kids cooking this #EasterWeeke...
# 7      0.712     0.000  RT @BBCTaster: We've just released a host of a...
# 8      0.466     0.534         ✊ Plastic protest! https://t.co/9m59wayYH8
# 9      1.000     0.000  RT @bbcarts: This Picture Wall in Lahore, Paki...
# 10     1.000     0.000  RT @bbcwritersroom: #OrdealByInnocence begins ...
# 11     1.000     0.000  RT @bbcideas: Author Lionel Shriver says we pr...
# 12     1.000     0.000  RT @BBCTwo: Imagine living in this incredible ...
# 13     1.000     0.000  😂 So, who's going out tonight? https://t.co/u2...
# 14     1.000     0.000  🎹🎶 Why it's never too late to learn an instrum...
# 15     1.000     0.000  RT @bbcpress: Everyone's favourite fox reads o...
# 16     0.701     0.000  Happy birthday to Alfred and Robert! 🎈 🎉 Brita...
# 17     0.581     0.295  This bizarrely cute creature is just the lates...
# 18     0.769     0.000  RT @BBCRadio2: Today we say farewell to the br...
# 19     0.655     0.000  🐶❤️ Biscuit the robotic pup is helping the eld...
# 20     1.000     0.000  👀🌸 The world famous cherry blossoms of Japan b...
# 21     1.000     0.000  What do you get if you cross a polar bear and ...
# 22     1.000     0.000  🇮🇪 This 800-year-old hotel in Ireland is simpl...
# 23     0.891     0.000  📚 'Words do not live in dictionaries. They liv...
# 24     0.688     0.312  The government rates the global outbreak of a ...
# 25     1.000     0.000     Slacking off in Dubai. https://t.co/a3oSKIxfSK
# 26     0.720     0.000  RT @BBCTheOneShow: The fantastic @george_ezra ...
# 27     1.000     0.000  Two-thirds of drivers say they are "regularly ...
# 28     0.887     0.113  The Masked Plumber is back. \nAnd this time, h...
# 29     1.000     0.000  RT @bbceurovision: We are starting a #Eurovisi...
# ..       ...       ...                                                ...
# 470    1.000     0.000  Heineken pulled a series of commercials for li...
# 471    0.675     0.000  President Trump called Roseanne Barr to congra...
# 472    1.000     0.000  RT @nytimesworld: For the first time since mil...
# 473    1.000     0.000  North Korea’s leader, Kim Jong-un, and Preside...
# 474    1.000     0.000  In Opinion\n\nDavid J. Shulkin writes: "In rec...
# 475    1.000     0.000  Indian officials have been ordered to stay awa...
# 476    1.000     0.000  Morning Briefing: Here's what you need to know...
# 477    0.875     0.125  "He threatened to burn down my house with me i...
# 478    0.853     0.147  Ecuador suspended internet access for Julian A...
# 479    0.652     0.348  At least 68 people died when a fire erupted du...
# 480    0.885     0.000  President Trump's lawyer discussed pardons for...
# 481    0.729     0.271  An emergency medical worker who was exposed to...
# 482    1.000     0.000  Malala Yousafzai, the Pakistani activist for g...
# 483    0.737     0.000  Thousands gathered in Paris to honor Mireille ...
# 484    0.845     0.155  All the major firings and resignations in the ...
# 485    0.829     0.171  A Nazi-era law makes it a crime for German doc...
# 486    0.792     0.208  The traditional Cambodian hatred of the ethnic...
# 487    1.000     0.000  North and South Korea Set a Date for Summit Me...
# 488    0.646     0.138  RT @nytimesworld: “She survived the Holocaust ...
# 489    0.556     0.000  5 Cheap(ish) Things to Help You Become a Bette...
# 490    0.531     0.318  A waiter was fired for being combative, aggres...
# 491    0.830     0.000  RT @nytimesworld: Which makes sense? a) Pirate...
# 492    1.000     0.000  Archaeologists believe the 13,000-year-old hum...
# 493    0.917     0.000  RT @NYTmag: Floating villages spread across th...
# 494    0.756     0.000  These arctic foxes turned "blue." It was a goo...
# 495    1.000     0.000  2 Texas oil companies joined forces in the big...
# 496    0.533     0.393  RT @EricSchmittNYT: American drone strike in L...
# 497    1.000     0.000  Steven Spielberg "is the only person who could...
# 498    1.000     0.000  Anbang Was Seized by China. Now, It Has a Deal...
# 499    0.672     0.000  RT @maggieNYT: Trump called a supporter with a...
#
# [500 rows x 8 columns]

# %%
BBC_df = sent_df.groupby(["User"]).get_group("@BBC")
CBS_df = sent_df.groupby(["User"]).get_group("@CBS")
CNN_df = sent_df.groupby(["User"]).get_group("@CNN")
FOX_df = sent_df.groupby(["User"]).get_group("@FoxNews")
NYT_df = sent_df.groupby(["User"]).get_group("@NYTimes")

# %%
plt.plot(BBC_df["Tweets Ago"],BBC_df["Compound"],marker="o",linewidth=0,color="lightblue")
plt.plot(CBS_df["Tweets Ago"],CBS_df["Compound"],marker="o",linewidth=0,color="green")
plt.plot(CNN_df["Tweets Ago"],CNN_df["Compound"],marker="o",linewidth=0,color="red")
plt.plot(FOX_df["Tweets Ago"],FOX_df["Compound"],marker="o",linewidth=0,color="blue")
plt.plot(NYT_df["Tweets Ago"],NYT_df["Compound"],marker="o",linewidth=0,color="yellow")
plt.grid()
plt.show()
#add legend and labels etc
